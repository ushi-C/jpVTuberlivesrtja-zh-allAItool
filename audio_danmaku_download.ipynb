# %% [markdown]
# # 📥 素材下载
# 下载直播回放音频 + 弹幕 JSON，供 `run.ipynb` 使用。
#
# **使用步骤**：
# 1. 格子①安装 yt-dlp
# 2. 格子②输入 URL，查看可用格式
# 3. 格子③下载音频（默认 `-f 140` 即 m4a，按格子②给出的格式列表修改）
# 4. 格子④下载弹幕 JSON
# 5. 完毕后前往 `run.ipynb` 继续

# %%
# ① 安装 yt-dlp
# !pip install yt-dlp -q
# !apt-get install -y nodejs -q

# %%
# ② 输入 URL & 查看可用格式
url = input('输入直播回放 URL：').strip()
# !yt-dlp -F "{url}"

# %%
# ③ 下载音频
# 默认 -f 140（m4a 音频），可根据上方格式列表修改格式 ID
# !yt-dlp -f 140 -o "%(title)s.%(ext)s" "{url}"

# %%
# ④ 下载弹幕 JSON
# !yt-dlp --write-subs --sub-langs live_chat --sub-format json --skip-download "{url}"
print('\n✅ 下载完毕，请前往 run.ipynb 继续处理。')
